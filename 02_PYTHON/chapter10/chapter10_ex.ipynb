# %% [markdown]
# # 10장 실습
# ---

# %%
with open("diary.txt", "w", encoding="UTF-8") as fp:
    fp.write("1. 비동기와 멀티스레드는 다른거다\n2. 컨텍스트는 현재 작업에 필요한 객체,상태, 기능에 접근할 수 있도록 묶어서 전달하는 작업환경이다.\n3. 게임 개발해주는 AI를 만들고싶다 현대의 엔진형식을 섞어서")

with open("diary.txt", "r", encoding="UTF-8") as fp:
    diary_txt = fp.read()
    print(diary_txt)

# %%
import csv

frutis_info = [["사과", "사과는 달아"], ["배", "배는 시원해"], ["오렌지", "오렌지는 셔"]]

with open("fruit_inventory.csv", "w", encoding="UTF-8", newline="") as fp:
    writer = csv.writer(fp)
    writer.writerows(frutis_info)

with open("fruit_inventory.csv", "r", encoding="UTF-8", newline="") as fp:
    reader = csv.reader(fp)
    print(*list(reader))

# %%
import json

player_info = {"캐릭터 이름" : "석호", "레벨" : 10, "관리자 권한" : True}

with open("character_profile.json", "w", encoding="UTF-8") as fp:
    json.dump(player_info, fp, indent=4, ensure_ascii=False)

with open("character_profile.json", "r", encoding="UTF-8") as fp:
    player_info_json = json.load(fp)
    print(player_info_json, type(player_info_json))

# %%
import pandas as pd

exercise_time_by_day = {
    "요일" : ["월요일", "화요일", "수요일", "목요일", "금요일"],
    "운동시간" : [10, 20, 30, 40, 50]
}

dt_exercise_time_by_day = pd.DataFrame(exercise_time_by_day)
print(dt_exercise_time_by_day.info())
print(dt_exercise_time_by_day.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   요일      5 non-null      str
#  1   운동시간    5 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 257.0 bytes
# None
#             운동시간
# count   5.000000
# mean   30.000000
# std    15.811388
# min    10.000000
# 25%    20.000000
# 50%    30.000000
# 75%    40.000000
# max    50.000000

# %%
from matplotlib import pyplot as plt

x_axis = ["1day", "2day", "3day"]
y_axis = [100, 250, 300]

plt.plot(x_axis, y_axis)
plt.title("Online mall visitors")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

dt_monthly_sales_data = pd.DataFrame({
    "month_data" : [100, 200, 300, 500],
    "sales_data" : [220, 280, 123, 411]
})


plt.plot(dt_monthly_sales_data.month_data, label="Month Data", marker='o')
plt.plot(dt_monthly_sales_data.sales_data, label="Sales Data", marker='o')
plt.xlabel('month')
plt.ylabel('sale')
plt.legend()
plt.show()
