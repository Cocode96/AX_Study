# %% [markdown]
# # 1장 3강

# %%
print("hello!")
# Out:
# hello!

# %%
print("world!")
print ("hello world!")
sum = 1 + 2
add = 1 + 2
mod = 5 % 2
apple = 1
print (apple)
# Out:
# world!
# hello world!
# 1
