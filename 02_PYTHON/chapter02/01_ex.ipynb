# %% [markdown]
# # 실습
# -----

# %%
print("Hello from first-project!")

# %%
print("name : 이 프로젝트의 상위 폴더 이름" + "\n" + "requires-python : 이 프로젝트에서 요구하는 최소 파이썬 버전")

# %%
def main():
   print("메인 함수입니다.")

def main():
   print("메인 함수 도플갱어입니다.")
# 이거 두개가 어떻게 공존하는지..
# 예상으론 변수도 바인딩된 객체를 가르키는 이름 이니까
# main() 이라고 정의되어있지만 c++의 메인이아닌 그저 main이라는 이름의 정의된 함수 이름
# 이 교체된거 아닐까.. 하는 추측

def tmp():
    print("난 메인 함수 아님")

# 메인이 없을때 이녀석은 왜 작동안하는지..
if __name__ != "__main__":
    print("아니지롱")
 
# 이녀석은 왜 작동안하는지.. 그냥 계속 안함..
# 이건 진짜 모름..
    tmp()

# 마지막 main 정의한게 들어옴
    main()

# %% [markdown]
# hana_na@teamsparta.co 이력서 포트폴리오 커리어 물어볼곳

# %%
__name__
# Out:
# '__main__'

# %%
main
# Out:
# <function __main__.main()>

# %%
main = 100

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 main()
#
# TypeError: 'int' object is not callable
