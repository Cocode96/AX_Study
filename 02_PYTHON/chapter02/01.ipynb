# %%
x = 5000
x
# Out:
# 5000

# %%
hex(id(x))
# Out:
# '0x101cfcefbf0'

# %%
y = x
y
print(hex(id(y)))
# Out:
# 0x101cfcefbf0

# %%
x = 500;
print(hex(id(x)));
# Out:
# 0x101cfcee390

# %%
x = 600;
print(hex(id(x)));
# Out:
# 0x101cfcef870

# %%
a = 10;
print(hex(id(a)));
# Out:
# 0x7ffb2d7c14c8

# %%
a = 20;
print(hex(id(a)));
# Out:
# 0x7ffb2d7c1608

# %%
a = 10;
print(hex(id(a)));

# %%
number_of_students = 100
type(number_of_students)

# %%
pi = 3.14
type(pi)

# %%
result = True
type(result)
# Out:
# bool

# %%
pi = "원주율"
type(pi)
# Out:
# str
