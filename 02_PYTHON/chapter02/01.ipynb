# %%
x = 5000
x

# %%
hex(id(x))

# %%
y = x
y
print(hex(id(y)))

# %%
x = 500;
print(hex(id(x)));
# Out:
# 0x260985ba890

# %%
x = 600;
print(hex(id(x)));
# Out:
# 0x260985badb0

# %%
a = 10;
print(hex(id(a)));
# Out:
# 0x7ffb2d7c14c8

# %%
a = 20;
print(hex(id(a)));
# Out:
# 0x7ffb2d7c1608

# %%
a = 10;
print(hex(id(a)));
# Out:
# 0x7ffb2d7c14c8
