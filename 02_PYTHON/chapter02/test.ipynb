# %% [markdown]
# # 실습 테스트
# ----

# %%
user_name = 20
product_price = 5000

user_name, product_price
# Out:
# (20, 5000)

# %%
x = 10
print(type(x))

x = "Hello"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 20
print(id(age))

age = 25
print(id(age))
# Out:
# 140717308646920
# 140717308647080

# %%
name = "양석호"
age = 30

message = "내 나이는 " + str(age) + "살입니다" 
print(message)
# Out:
# 내 나이는 30살입니다

# %%
result = 10 + 3.14
print(result)
print(int(result))
# Out:
# 13.14
# 13

# %%
user_input = "25"
if user_input.isdigit():
    age = int(user_input)
    print("정수 전환 성공")
else:
    print("숫자만 입력해 주세요!")
# Out:
# 정수 전환 성공

# %%
count = 10
count *= 5
print(count)
# Out:
# 50

# %%
print("apple" < "banna")
# Out:
# True

# %%
result = False and 500 / 0
print(result)
# Out:
# False

# %%
menu_name = "Americano"
menu_price = 4500

print("상품 : %s | 가격 : %d원" % (menu_name, menu_price))
print(f"상품 : {menu_name} | 가격 : {menu_price}원")
# Out:
# 상품 : Americano | 가격 : 4500원
# 상품 : Americano | 가격 : 4500원

# %%
price = 15000

print(f"금액 : {price:>8,}원")
# Out:
# 금액 :   15,000원

# %%
current_status = "정상 진행중"
price = 6500

print(f"디버깅 로그 -> 현재 상태 : {current_status=}, 가격 : {price=}")
# Out:
# 디버깅 로그 -> 현재 상태 : current_status='정상 진행중', 가격 : price=6500

# %% [markdown]
# Hellow world
