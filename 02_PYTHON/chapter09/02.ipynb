# %% [markdown]
# ## 9장 2강 : 표준 라이브러리

# %% [markdown]
# ### 1. [날짜와 시간] datetime & time
# - datetime : 모듈명
#     - 날짜와 시간 : datetime
#     - 날짜 : date
#     - 시간 : time
#     - 시간 변화량 : timedelta
#     ...

# %% [markdown]
# ### 2. [수학 연산] math

# %% [markdown]
# ### 3. [데이터 표준 변환] json
# - 다른 플랫폼(파이썬, 자바, c#, c++...) 간의 소통을 위한 표준 데이터 형식
# - 자바스크립트의 객체를 정의하는 형식을 빌려온것

# %%
import json

user = {
    "name" : "철수",
    "age" : 20
}

json_string = json.dumps(user, ensure_ascii=False)
print("json_string:", json_string, "type:", type(json_string))
# Out:
# json_string: {"name": "철수", "age": 20} type: <class 'str'>

# %%
#json 문자열 -> 파이썬 객체
nums_string = "[1,2,3,4,5]"
user_string = '{"name": "김철수", "age" : 20}'

nums = json.loads(nums_string)
user2 = json.loads(user_string)

print("nums:",nums, "type:", type(nums))
print("user2:",user2, "type:", type(user2))
# Out:
# nums: [1, 2, 3, 4, 5] type: <class 'list'>
# user2: {'name': '김철수', 'age': 20} type: <class 'dict'>

# %% [markdown]
# ### 4. [무작위 난수 추출] random

# %% [markdown]
# ### 5. [시스템 및 파일 제어] os & sys
